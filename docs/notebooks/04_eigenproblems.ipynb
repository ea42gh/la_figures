# %% [markdown]
# # Eigenproblems
# Comprehensive eigen/SVD parameters.
#
# Parameters: `normal`, `Ascale`, `eig_digits`, `vec_digits`.

# %%
import sympy as sym
import la_figures
from IPython.display import SVG, display
from matrixlayout import eigproblem_svg

# %%
A = sym.Matrix([[2, 0], [0, 3]])
spec = la_figures.eig_tbl_spec(A, normal=False)

svg = eigproblem_svg(spec, case="S")
display(SVG(svg))
