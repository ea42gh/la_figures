# %% [markdown]
# # Algorithms overview
# Inspect trace outputs from the algorithm layer.

# %%
import sympy as sym
import la_figures

# %%
A = sym.Matrix([[1, 2], [3, 4]])
tr = la_figures.ge_trace(A, pivoting="none")
layers = la_figures.trace_to_layer_matrices(tr, augmented=True)
layers
# Out:
# {'matrices': [[None,
#    Matrix([
#    [1, 2],
#    [3, 4]])],
#   [Matrix([
#    [ 1, 0],
#    [-3, 1]]),
#    Matrix([
#    [1,  2],
#    [0, -2]])]],
#  'Nrhs': 0,
#  'pivot_positions': [(0, 0), (1, 1)],
#  'pivot_cols': [0, 1],
#  'free_cols': [],
#  'meta': {'shape': (2, 2),
#   'aug_shape': (2, 2),
#   'rank': 2,
#   'pivoting': 'none',
#   'gj': False}}
